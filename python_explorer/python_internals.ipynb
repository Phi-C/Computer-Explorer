# %% [markdown]
# ## Python Bytecode 字节码
# 字节码是 Python 源代码编译后生成的低级指令集（类似于汇编语言），由 Python 虚拟机执行.
# 特点：
# 1. 存储在 .pyc 文件中（Python 缓存文件）。
#
# 2. 由一系列操作码（opcode）组成，如 LOAD_FAST、CALL_FUNCTION 等。
#
# 3. 可通过 dis 模块反汇编查看

# %%
def add(a, b):
    return a + b

print(add(2, 3))
# Out:
# 5

# %%
import dis

dis.dis(add)
# Out:
#   2           0 LOAD_FAST                0 (a)
#               2 LOAD_FAST                1 (b)
#               4 BINARY_ADD
#               6 RETURN_VALUE

# %%
dis.dis(add.__code__)
# Out:
#   2           0 LOAD_FAST                0 (a)
#               2 LOAD_FAST                1 (b)
#               4 BINARY_ADD
#               6 RETURN_VALUE

# %%
def outer(aa):
    def inner():
        bb = 1
        return aa + bb + cc
    return inner

# 机器上运行的二进制
print(outer.__code__.co_code)

# 看汇编(人类可读)
dis.dis(outer.__code__)
# Out:
# b'\x87\x00f\x01d\x01d\x02\x84\x08}\x01|\x01S\x00'
#   2           0 LOAD_CLOSURE             0 (aa)
#               2 BUILD_TUPLE              1
#               4 LOAD_CONST               1 (<code object inner at 0x7fa9a0a38a80, file "<ipython-input-23-3e90f112e3d3>", line 2>)
#               6 LOAD_CONST               2 ('outer.<locals>.inner')
#               8 MAKE_FUNCTION            8 (closure)
#              10 STORE_FAST               1 (inner)
#
#   5          12 LOAD_FAST                1 (inner)
#              14 RETURN_VALUE
#
# Disassembly of <code object inner at 0x7fa9a0a38a80, file "<ipython-input-23-3e90f112e3d3>", line 2>:
#   3           0 LOAD_CONST               1 (1)
#               2 STORE_FAST               0 (bb)
#
#   4           4 LOAD_DEREF               0 (aa)
#               6 LOAD_FAST                0 (bb)
#               8 BINARY_ADD
#              10 LOAD_GLOBAL              0 (cc)
#              12 BINARY_ADD
#              14 RETURN_VALUE

# %% [markdown]
# 注意到，在python的字节码中, `aa`(在inner的enclosing cope) 、`bb`(在inner的local scope)和`cc`(在inner的global scope)分别使用了不同的不同的指令(OP_CODE)来将变俩个加载到堆栈里:
# * aa: `LOAD_DEREF`
# * bb: `LOAD_FAST`
# * cc: `LOAD_GLOBAL`
#
# REF: https://docs.python.org/zh-cn/3.13/library/dis.html#python-bytecode-instructions
#
# PS:
# * python的作用域(scope)遵循LEGB原则: Local -> Enclosing -> Global -> Bultin

# %%
source_code = """
def toy_example(a, b):
    x = a / (torch.abs(a) + 1)
    if b.sum() < 0:
        b = b * -1
    return x * b
"""

# co 意为 code object: 从源码到code object
# source_code -> parse tree generation -> AST generation -> bytecode generaton
# -> bytecode optimization -> code object generation -> code object execution
co = compile(source_code, "<string>", "exec")

print(f"type(co) = {type(co)}")
print(co)

# 字节码（二进制形式）
print(f"type(co.co_code) = {type(co.co_code)}")
print(co.co_code)

import dis
dis.dis(co)
# Out:
# type(co) = <class 'code'>
# <code object <module> at 0x7fa9a0a39450, file "<string>", line 2>
# type(co.co_code) = <class 'bytes'>
# b'd\x00d\x01\x84\x00Z\x00d\x02S\x00'
#   2           0 LOAD_CONST               0 (<code object toy_example at 0x7fa9a0a34df0, file "<string>", line 2>)
#               2 LOAD_CONST               1 ('toy_example')
#               4 MAKE_FUNCTION            0
#               6 STORE_NAME               0 (toy_example)
#               8 LOAD_CONST               2 (None)
#              10 RETURN_VALUE
#
# Disassembly of <code object toy_example at 0x7fa9a0a34df0, file "<string>", line 2>:
#   3           0 LOAD_FAST                0 (a)
#               2 LOAD_GLOBAL              0 (torch)
#               4 LOAD_METHOD              1 (abs)
#               6 LOAD_FAST                0 (a)
#               8 CALL_METHOD              1
#              10 LOAD_CONST               1 (1)
#              12 BINARY_ADD
#              14 BINARY_TRUE_DIVIDE
#              16 STORE_FAST               2 (x)
#
#   4          18 LOAD_FAST                1 (b)
#              20 LOAD_METHOD              2 (sum)
#              22 CALL_METHOD              0
#              24 LOAD_CONST               2 (0)
#              26 COMPARE_OP               0 (<)
#              28 POP_JUMP_IF_FALSE       38
#
#   5          30 LOAD_FAST                1 (b)
#              32 LOAD_CONST               3 (-1)
#              34 BINARY_MULTIPLY
#              36 STORE_FAST               1 (b)
#
#   6     >>   38 LOAD_FAST                2 (x)
#              40 LOAD_FAST                1 (b)
#              42 BINARY_MULTIPLY
#              44 RETURN_VALUE

# %% [markdown]
# ## Python code object 代码对象
# Code Object 是 Python 内部用于存储代码块（如函数、模块、类）的元数据和字节码的对象。可通过 function.__code__ 或 compile() 获取。
#
# | 特性          | 字节码（Bytecode）                          | Code Object（代码对象）                     |
# |---------------|-------------------------------------------|--------------------------------------------|
# | **存储形式**  | 二进制指令（`bytes`）                      | Python 对象（`types.CodeType`）             |
# | **包含内容**  | 纯操作码（opcode）                         | 字节码 + 元数据（变量名、常量等）            |
# | **获取方式**  | `func.__code__.co_code`                   | `func.__code__` 或 `compile()`              |
# | **用途**      | 直接由 Python 虚拟机（PVM）执行            | 存储完整代码块信息（字节码 + 执行环境）       |
#
# REF: https://docs.python.org/zh-cn/3.13/library/inspect.html

# %%
def mul(a, b):
    return a * b

code = mul.__code__
print(code.co_argcount)
print(code.co_posonlyargcount)
print(code.co_kwonlyargcount)
# Out:
# 2
# 0
# 0

# %%
# / 表示它之前的arguments都是positional-only arguments
def mul(a, b, /, *args, **kwargs):
    return a * b

code = mul.__code__
print(code.co_argcount)
print(code.co_posonlyargcount)
print(code.co_kwonlyargcount)
# Out:
# 2
# 2
# 0

# %%
# * 表示它之后的arguments都是keyword arguments
def mul(a, *, b = 1, **kwargs):
    return a * b

code = mul.__code__
# co_argcount 表示除了* 、**以及keyword arguments之外的所有的参数数量
print(code.co_argcount)
print(code.co_posonlyargcount)
print(code.co_kwonlyargcount)
# Out:
# 1
# 0
# 1

# %%
def g():
    d = {}
    def f():
        d["a"] = 1
    return f


def get_code_info(code):
    print(f"nlocals: {code.co_nlocals}")

    print(f"varnames: {code.co_varnames}")
    print(f"names: {code.co_names}")

    # cellvars: 这个variable会在其他scope用到
    # freezers: 这个variable来自其他scope
    print(f"cellvars: {code.co_cellvars}")
    print(f"freears: {code.co_freevars}")

    print(f"consts: {code.co_consts}")

# obj = g()
# obj is function f
# code = g().__code__
code = g().__code__
get_code_info(code)

print(f"===================")

code = g.__code__
get_code_info(code)
# Out:
# nlocals: 0
# varnames: ()
# names: ()
# cellvars: ()
# freears: ('d',)
# consts: (None, 1, 'a')
# ===================
# nlocals: 1
# varnames: ('f',)
# names: ()
# cellvars: ('d',)
# freears: ()
# consts: (None, <code object f at 0x7fa990989710, file "<ipython-input-42-ac2699e2254f>", line 3>, 'g.<locals>.f')

# %%
def g():
    d = {}
    def f():
        # 如果f里面没有使用d, 那么d就是一个varnames, 而不是一个cellvars
        # d["a"] = 1
        pass
    return f

def get_code_info(code):
    print(f"nlocals: {code.co_nlocals}")

    print(f"varnames: {code.co_varnames}")
    print(f"names: {code.co_names}")

    # cellvars: 这个variable会在其他scope用到
    # freezers: 这个variable来自其他scope
    print(f"cellvars: {code.co_cellvars}")
    print(f"freears: {code.co_freevars}")

    print(f"consts: {code.co_consts}")

code = g.__code__
get_code_info(code)
# Out:
# nlocals: 2
# varnames: ('d', 'f')
# names: ()
# cellvars: ()
# freears: ()
# consts: (None, <code object f at 0x7fa9909897c0, file "<ipython-input-45-903b2902fdda>", line 3>, 'g.<locals>.f')

# %% [markdown]
# ## Python frame
# 1. 每个函数只会编译出来一个code object, 它是immutable的
# 2. frame会记录函数执行的一些状态信息, 每次函数调用的状态可能都不太一样
#
# 获取了python frame后, 对其内容进行解析, 可以做很多有意思的事情

# %%
# 最好在运行.py文件, 不要在Jupyter Notebook允许这段代码
import inspect
from objprint import op

def f():
    frame = inspect.currentframe()

    op(
        frame,
        honor_existing=False,
        depth=2
    )

f()
# Out:
# <frame 0x7fa95a760a70
#   .f_back = <frame 0x7fa97a70b750
#     .f_back = <frame 0x7fa95a761140 ... >,
#     .f_builtins = { ... },
#     .f_code = <code 0x7fa9806fbf50 ... >,
#     .f_globals = { ... },
#     .f_lasti = 2,
#     .f_lineno = 14,
#     .f_locals = { ... },
#     .f_trace = None,
#     .f_trace_lines = True,
#     .f_trace_opcodes = False
#   >,
#   .f_builtins = {
#     'ArithmeticError': <type 0x1031894f0 ... >,
#     'AssertionError': <type 0x103189348 ... >,
#     'AttributeError': <type 0x103185de8 ... >,
#     'BaseException': <type 0x103184370 ... >,
#     'BlockingIOError': <type 0x103185c40 ... >,
#     'BrokenPipeError': <type 0x1031862e0 ... >,
#     'BufferError': <type 0x10318a088 ... >,
#     'BytesWarning': <type 0x10318b118 ... >,
#     'ChildProcessError': <type 0x103186138 ... >,
#     'ConnectionAbortedError': <type 0x103186488 ... >,
#     'ConnectionError': <type 0x103185f90 ... >,
#     'ConnectionRefusedError': <type 0x103186630 ... >,
#     'ConnectionResetError': <type 0x1031867d8 ... >,
#     'DeprecationWarning': <type 0x10318a580 ... >,
#     'EOFError': <type 0x1031876c0 ... >,
#     'Ellipsis': <ellipsis 0x103194e20 ... >,
#     'EnvironmentError': <type 0x103185788 ... >,
#     'Exception': <type 0x103184878 ... >,
#     'False': False,
#     'FileExistsError': <type 0x103186980 ... >,
#     'FileNotFoundError': <type 0x103186b28 ... >,
#     'FloatingPointError': <type 0x103189698 ... >,
#     'FutureWarning': <type 0x10318ac20 ... >,
#     'GeneratorExit': <type 0x103184dc8 ... >,
#     'IOError': <type 0x103185788 ... >,
#     'ImportError': <type 0x103185310 ... >,
#     'ImportWarning': <type 0x10318adc8 ... >,
#     'IndentationError': <type 0x1031886b8 ... >,
#     'IndexError': <type 0x103188370 ... >,
#     'InterruptedError': <type 0x103187020 ... >,
#     'IsADirectoryError': <type 0x103186cd0 ... >,
#     'KeyError': <type 0x103188a10 ... >,
#     'KeyboardInterrupt': <type 0x103185168 ... >,
#     'LookupError': <type 0x103188510 ... >,
#     'MemoryError': <type 0x103189ee0 ... >,
#     'ModuleNotFoundError': <type 0x1031855e0 ... >,
#     'NameError': <type 0x103187d60 ... >,
#     'None': None,
#     'NotADirectoryError': <type 0x103186e78 ... >,
#     'NotImplemented': <NotImplementedType 0x103192fb0 ... >,
#     'NotImplementedError': <type 0x103187bb8 ... >,
#     'OSError': <type 0x103185788 ... >,
#     'OverflowError': <type 0x103189840 ... >,
#     'PendingDeprecationWarning': <type 0x10318a728 ... >,
#     'PermissionError': <type 0x1031871c8 ... >,
#     'ProcessLookupError': <type 0x103187370 ... >,
#     'RecursionError': <type 0x103187a10 ... >,
#     'ReferenceError': <type 0x103189d38 ... >,
#     'ResourceWarning': <type 0x10318b2c0 ... >,
#     'RuntimeError': <type 0x103187868 ... >,
#     'RuntimeWarning': <type 0x10318aa78 ... >,
#     'StopAsyncIteration': <type 0x103184a28 ... >,
#     'StopIteration': <type 0x103184bd0 ... >,
#     'SyntaxError': <type 0x1031880b0 ... >,
#     'SyntaxWarning': <type 0x10318a8d0 ... >,
#     'SystemError': <type 0x103189b90 ... >,
#     'SystemExit': <type 0x103184f70 ... >,
#     'TabError': <type 0x103188860 ... >,
#     'TimeoutError': <type 0x103187518 ... >,
#     'True': True,
#     'TypeError': <type 0x1031846d8 ... >,
#     'UnboundLocalError': <type 0x103187f08 ... >,
#     'UnicodeDecodeError': <type 0x103188ff8 ... >,
#     'UnicodeEncodeError': <type 0x103188d60 ... >,
#     'UnicodeError': <type 0x103188bb8 ... >,
#     'UnicodeTranslateError': <type 0x1031891a0 ... >,
#     'UnicodeWarning': <type 0x10318af70 ... >,
#     'UserWarning': <type 0x10318a3d8 ... >,
#     'ValueError': <type 0x103185aa0 ... >,
#     'Warning': <type 0x10318a230 ... >,
#     'ZeroDivisionError': <type 0x1031899e8 ... >,
#     '__IPYTHON__': True,
#     '__build_class__': <builtin_function_or_method 0x7fa9b0076090 ... >,
#     '__debug__': True,
#     '__doc__': 'Built-in functions, exceptions, and other objects.
#
# Noteworthy: None is the `nil' object; Ellipsis represents `...' in slices.',
#     '__import__': <builtin_function_or_method 0x7fa9b00760e0 ... >,
#     '__loader__': <type 0x7fa9ab905820 ... >,
#     '__name__': 'builtins',
#     '__package__': '',
#     '__spec__': <ModuleSpec 0x7fa9b007c0a0 ... >,
#     'abs': <builtin_function_or_method 0x7fa9b0076130 ... >,
#     'all': <builtin_function_or_method 0x7fa9b0076180 ... >,
#     'any': <builtin_function_or_method 0x7fa9b00761d0 ... >,
#     'ascii': <builtin_function_or_method 0x7fa9b0076220 ... >,
#     'bin': <builtin_function_or_method 0x7fa9b0076270 ... >,
#     'bool': <type 0x10317f9d8 ... >,
#     'breakpoint': <builtin_function_or_method 0x7fa9b00762c0 ... >,
#     'bytearray': <type 0x10317fcb8 ... >,
#     'bytes': <type 0x103180ac8 ... >,
#     'callable': <builtin_function_or_method 0x7fa9b0076310 ... >,
#     'chr': <builtin_function_or_method 0x7fa9b0076360 ... >,
#     'classmethod': <type 0x10318d870 ... >,
#     'compile': <builtin_function_or_method 0x7fa9b00763b0 ... >,
#     'complex': <type 0x103182548 ... >,
#     'copyright': <_Printer 0x7fa990075d90 ... >,
#     'credits': <_Printer 0x7fa9901651f0 ... >,
#     'delattr': <builtin_function_or_method 0x7fa9b0076400 ... >,
#     'dict': <type 0x10318f470 ... >,
#     'dir': <builtin_function_or_method 0x7fa9b0076450 ... >,
#     'display': <function display>,
#     'divmod': <builtin_function_or_method 0x7fa9b00764a0 ... >,
#     'enumerate': <type 0x103183f08 ... >,
#     'eval': <builtin_function_or_method 0x7fa9b00764f0 ... >,
#     'exec': <builtin_function_or_method 0x7fa9b0076540 ... >,
#     'filter': <type 0x10319ad80 ... >,
#     'float': <type 0x10318cad8 ... >,
#     'format': <builtin_function_or_method 0x7fa9b0076590 ... >,
#     'frozenset': <type 0x1031947e0 ... >,
#     'get_ipython': <method 0x7fa9b07fefc0 ... >,
#     'getattr': <builtin_function_or_method 0x7fa9b00765e0 ... >,
#     'globals': <builtin_function_or_method 0x7fa9b0076630 ... >,
#     'hasattr': <builtin_function_or_method 0x7fa9b0076680 ... >,
#     'hash': <builtin_function_or_method 0x7fa9b00766d0 ... >,
#     'help': <_Helper 0x7fa99012a7c0 ... >,
#     'hex': <builtin_function_or_method 0x7fa9b0076720 ... >,
#     'id': <builtin_function_or_method 0x7fa9b0076770 ... >,
#     'input': <method 0x7fa9a0791d00 ... >,
#     'int': <type 0x10318ed00 ... >,
#     'isinstance': <builtin_function_or_method 0x7fa9b0076810 ... >,
#     'issubclass': <builtin_function_or_method 0x7fa9b0076860 ... >,
#     'iter': <builtin_function_or_method 0x7fa9b00768b0 ... >,
#     'len': <builtin_function_or_method 0x7fa9b0076900 ... >,
#     'license': <_Printer 0x7fa990137280 ... >,
#     'list': <type 0x10318e468 ... >,
#     'locals': <builtin_function_or_method 0x7fa9b0076950 ... >,
#     'map': <type 0x10319af60 ... >,
#     'max': <builtin_function_or_method 0x7fa9b00769a0 ... >,
#     'memoryview': <type 0x103191a30 ... >,
#     'min': <builtin_function_or_method 0x7fa9b00769f0 ... >,
#     'next': <builtin_function_or_method 0x7fa9b0076a40 ... >,
#     'object': <type 0x103195668 ... >,
#     'oct': <builtin_function_or_method 0x7fa9b0076a90 ... >,
#     'open': <builtin_function_or_method 0x7fa9b0070450 ... >,
#     'ord': <builtin_function_or_method 0x7fa9b0076ae0 ... >,
#     'pow': <builtin_function_or_method 0x7fa9b0076b30 ... >,
#     'print': <builtin_function_or_method 0x7fa9b0076b80 ... >,
#     'property': <type 0x103183b68 ... >,
#     'range': <type 0x103193570 ... >,
#     'repr': <builtin_function_or_method 0x7fa9b0076bd0 ... >,
#     'reversed': <type 0x103184130 ... >,
#     'round': <builtin_function_or_method 0x7fa9b0076c20 ... >,
#     'set': <type 0x103194228 ... >,
#     'setattr': <builtin_function_or_method 0x7fa9b0076c70 ... >,
#     'slice': <type 0x103194e30 ... >,
#     'sorted': <builtin_function_or_method 0x7fa9b0076cc0 ... >,
#     'staticmethod': <type 0x10318dad8 ... >,
#     'str': <type 0x1031980f0 ... >,
#     'sum': <builtin_function_or_method 0x7fa9b0076d10 ... >,
#     'super': <type 0x103197eb0 ... >,
#     'tuple': <type 0x1031951a8 ... >,
#     'type': <type 0x103195808 ... >,
#     'vars': <builtin_function_or_method 0x7fa9b0076d60 ... >,
#     'zip': <type 0x10319b140 ... >
#   },
#   .f_code = <code 0x7fa9806fb7c0
#     .co_argcount = 0,
#     .co_cellvars = ( ... ),
#     .co_code = <bytes 0x7fa9806f1af0 ... >,
#     .co_consts = ( ... ),
#     .co_filename = '<ipython-input-52-e21c061761ae>',
#     .co_firstlineno = 4,
#     .co_flags = 67,
#     .co_freevars = ( ... ),
#     .co_kwonlyargcount = 0,
#     .co_lnotab = <bytes 0x7fa9909b92a0 ... >,
#     .co_name = 'f',
#     .co_names = ( ... ),
#     .co_nlocals = 1,
#     .co_posonlyargcount = 0,
#     .co_stacksize = 5,
#     .co_varnames = ( ... )
#   >,
#   .f_globals = {
#     'In': [ ... ],
#     'Out': { ... },
#     '_': '',
#     '__': '',
#     '___': '',
#     '__builtin__': <module 0x7fa9b0076040 ... >,
#     '__builtins__': <module 0x7fa9b0076040 ... >,
#     '__doc__': 'Automatically created module for IPython interactive environment',
#     '__loader__': None,
#     '__name__': '__main__',
#     '__package__': None,
#     '__spec__': None,
#     '__vsc_ipynb_file__': '/Users/xingjian/Documents/Code/Computer-Explorer/python_explorer/python_internals.ipynb',
#     '_dh': [ ... ],
#     '_i': 'import inspect
# from objprint import op
#
# def f():
#     frame = inspect.currentframe()
#     # print(frame)
#
#     op(
#         frame,
#         honor_existing=False,
#         depth=2
#     )
#
# f()',
#     '_i1': 'def add(a, b):
#     return a + b
#
# print(add(2 + 3))',
#     '_i10': 'def add(a, b):
#     return a + b
#
# print(add(2, 3))',
#     '_i11': 'import dis
#
# dis.dis(add)',
#     '_i12': 'dis.dis(add.__code__)',
#     '_i13': 'def outer(aa):
#     def inner():
#         bb = 1
#         return aa + bb + cc
#     return inner
#
# dis.dis(outer.__code__)',
#     '_i14': 'source_code = """
# def toy_example(a, b):
#     x = a / (torch.abs(a) + 1)
#     if b.sum() < 0:
#         b = b * -1
#     return x * b
# """
#
# # co 意为 code object
# co = compile(source_code, "<string>", "exec")
#
# # 字节码（二进制形式）
# print(co.co_code)
#
# import dis
# dis.dis(co)',
#     '_i15': 'source_code = """
# def toy_example(a, b):
#     x = a / (torch.abs(a) + 1)
#     if b.sum() < 0:
#         b = b * -1
#     return x * b
# """
#
# # co 意为 code object
# co = compile(source_code, "<string>", "exec")
#
# # 字节码（二进制形式）
# print(co.co_code)
#
# print(f"type(co) = {type(co)}")
# import dis
# dis.dis(co)',
#     '_i16': 'source_code = """
# def toy_example(a, b):
#     x = a / (torch.abs(a) + 1)
#     if b.sum() < 0:
#         b = b * -1
#     return x * b
# """
#
# # co 意为 code object
# co = compile(source_code, "<string>", "exec")
#
# # 字节码（二进制形式）
# print(f"type(co) = {type(co)}")
# print(f"type(co.co_code) = {type(co.co_code)}")
# print(co.co_code)
#
# import dis
# # dis.dis(co)',
#     '_i17': 'source_code = """
# def toy_example(a, b):
#     x = a / (torch.abs(a) + 1)
#     if b.sum() < 0:
#         b = b * -1
#     return x * b
# """
#
# # co 意为 code object
# co = compile(source_code, "<string>", "exec")
#
# # 字节码（二进制形式）
# print(f"type(co) = {type(co)}")
# print(f"type(co.co_code) = {type(co.co_code)}")
# print(co.co_code)
#
# import dis
# dis.dis(co.co_code)',
#     '_i18': 'source_code = """
# def toy_example(a, b):
#     x = a / (torch.abs(a) + 1)
#     if b.sum() < 0:
#         b = b * -1
#     return x * b
# """
#
# # co 意为 code object
# co = compile(source_code, "<string>", "exec")
#
# # 字节码（二进制形式）
# print(f"type(co) = {type(co)}")
# print(f"type(co.co_code) = {type(co.co_code)}")
# print(co.co_code)
# print(co)
#
# import dis
# dis.dis(co.co_code)',
#     '_i19': 'source_code = """
# def toy_example(a, b):
#     x = a / (torch.abs(a) + 1)
#     if b.sum() < 0:
#         b = b * -1
#     return x * b
# """
#
# # co 意为 code object
# co = compile(source_code, "<string>", "exec")
#
# # 字节码（二进制形式）
# print(f"type(co) = {type(co)}")
# print(co)
#
# print(f"type(co.co_code) = {type(co.co_code)}")
# print(co.co_code)
#
# import dis
# dis.dis(co.co_code)',
#     '_i2': 'def add(a, b):
#     return a + b
#
# print(add(2, 3))',
#     '_i20': 'source_code = """
# def toy_example(a, b):
#     x = a / (torch.abs(a) + 1)
#     if b.sum() < 0:
#         b = b * -1
#     return x * b
# """
#
# # co 意为 code object
# co = compile(source_code, "<string>", "exec")
#
# # 字节码（二进制形式）
# print(f"type(co) = {type(co)}")
# print(co)
#
# print(f"type(co.co_code) = {type(co.co_code)}")
# print(co.co_code)
#
# import dis
# dis.dis(co)',
#     '_i21': 'def outer(aa):
#     def inner():
#         bb = 1
#         return aa + bb + cc
#     return inner
#
# print(outer.__code__.co_code)
# dis.dis(outer.__code__)',
#     '_i22': 'source_code = """
# def toy_example(a, b):
#     x = a / (torch.abs(a) + 1)
#     if b.sum() < 0:
#         b = b * -1
#     return x * b
# """
#
# # co 意为 code object: 从源码到code object
# # source_code -> parse tree generation -> AST generation -> bytecode generaton
# # -> bytecode optimization -> code object generation -> code object execution
# co = compile(source_code, "<string>", "exec")
#
# print(f"type(co) = {type(co)}")
# print(co)
#
# # 字节码（二进制形式）
# print(f"type(co.co_code) = {type(co.co_code)}")
# print(co.co_code)
#
# import dis
# dis.dis(co)',
#     '_i23': 'def outer(aa):
#     def inner():
#         bb = 1
#         return aa + bb + cc
#     return inner
#
# # 机器上运行的二进制
# print(outer.__code__.co_code)
#
# # 看汇编(人类可读)
# dis.dis(outer.__code__)',
#     '_i24': 'source_code = """
# def toy_example(a, b):
#     x = a / (torch.abs(a) + 1)
#     if b.sum() < 0:
#         b = b * -1
#     return x * b
# """
#
# # co 意为 code object: 从源码到code object
# # source_code -> parse tree generation -> AST generation -> bytecode generaton
# # -> bytecode optimization -> code object generation -> code object execution
# co = compile(source_code, "<string>", "exec")
#
# print(f"type(co) = {type(co)}")
# print(co)
#
# # 字节码（二进制形式）
# print(f"type(co.co_code) = {type(co.co_code)}")
# print(co.co_code)
#
# import dis
# dis.dis(co)',
#     '_i25': 'def mul(a, b):
#     return a * b
#
# code = mul.__code__
# print(code.co_argcount)
# print(code.co_posonlyargcount)
# print(code.co_kwonlyargcount)',
#     '_i26': 'def mul(a, b):
#     return a * b
#
# code = mul.__code__
# print(code.co_argcount)
# print(code.co_posonlyargcount)
# print(code.co_kwonlyargcount)',
#     '_i27': 'def mul(a, b, /, *args, **kwargs):
#     return a * b
#
# code = mul.__code__
# print(code.co_argcount)
# print(code.co_posonlyargcount)
# print(code.co_kwonlyargcount)',
#     '_i28': '# / 表示它之前的arguments都是positional-only arguments
# def mul(a, *, b, *args, **kwargs):
#     return a * b
#
# code = mul.__code__
# print(code.co_argcount)
# print(code.co_posonlyargcount)
# print(code.co_kwonlyargcount)',
#     '_i29': '# / 表示它之前的arguments都是positional-only arguments
# def mul(a, *, b = 1, *args, **kwargs):
#     return a * b
#
# code = mul.__code__
# print(code.co_argcount)
# print(code.co_posonlyargcount)
# print(code.co_kwonlyargcount)',
#     '_i3': 'import dis
#
# dis.dis(add)',
#     '_i30': '# / 表示它之前的arguments都是positional-only arguments
# def mul(a, *, b = 1, **kwargs):
#     return a * b
#
# code = mul.__code__
# print(code.co_argcount)
# print(code.co_posonlyargcount)
# print(code.co_kwonlyargcount)',
#     '_i31': '# * 表示它之后的arguments都是keyword arguments
# def mul(a, *, b = 1, **kwargs):
#     return a * b
#
# code = mul.__code__
# print(code.co_argcount)
# print(code.co_posonlyargcount)
# print(code.co_kwonlyargcount)',
#     '_i32': '# * 表示它之后的arguments都是keyword arguments
# def mul(a, *, b = 1, **kwargs):
#     return a * b
#
# code = mul.__code__
# # co_argcount 表示除了* 、**以及keyword arguments之外的所有的参数数量
# print(code.co_argcount)
# print(code.co_posonlyargcount)
# print(code.co_kwonlyargcount)',
#     '_i33': 'def g():
#     d = {}
#     def f():
#         d["a"] = 1
#     return f
#
# code = g.__code__',
#     '_i34': 'def g():
#     d = {}
#     def f():
#         d["a"] = 1
#     return f
#
# code = g.__code__
#
# print(f"nlocals: {code.co_nlocals}")
#
# print(f"varnames: {code.co_varnames}"
# print(f"names: {code.co_names}"))
#
# print(f"cellvars: {code.co_cellvars}")
# print(f"freears: {code.co_freevars}")
#
# print(f"consts: {code.co_consts}")',
#     '_i35': 'def g():
#     d = {}
#     def f():
#         d["a"] = 1
#     return f
#
# code = g.__code__
#
# print(f"nlocals: {code.co_nlocals}")
#
# print(f"varnames: {code.co_varnames}")
# print(f"names: {code.co_names}")
#
# print(f"cellvars: {code.co_cellvars}")
# print(f"freears: {code.co_freevars}")
#
# print(f"consts: {code.co_consts}")',
#     '_i36': 'def g():
#     d = {}
#     def f():
#         d["a"] = 1
#     return f
#
# code = g().__code__
#
# print(f"nlocals: {code.co_nlocals}")
#
# print(f"varnames: {code.co_varnames}")
# print(f"names: {code.co_names}")
#
# print(f"cellvars: {code.co_cellvars}")
# print(f"freears: {code.co_freevars}")
#
# print(f"consts: {code.co_consts}")',
#     '_i37': 'def g():
#     d = {}
#     def f():
#         d["a"] = 1
#     return f
#
# code = g.__code__
#
# print(f"nlocals: {code.co_nlocals}")
#
# print(f"varnames: {code.co_varnames}")
# print(f"names: {code.co_names}")
#
# print(f"cellvars: {code.co_cellvars}")
# print(f"freears: {code.co_freevars}")
#
# print(f"consts: {code.co_consts}")',
#     '_i38': 'def g():
#     d = {}
#     def f():
#         d["a"] = 1
#     return f
#
# code = g().__code__
#
# print(f"nlocals: {code.co_nlocals}")
#
# print(f"varnames: {code.co_varnames}")
# print(f"names: {code.co_names}")
#
# print(f"cellvars: {code.co_cellvars}")
# print(f"freears: {code.co_freevars}")
#
# print(f"consts: {code.co_consts}")',
#     '_i39': 'def g():
#     d = {}
#     def f():
#         d["a"] = 1
#     return f
#
# print(teyp(g()))
# print(type(g))
#
# code = g().__code__
#
# print(f"nlocals: {code.co_nlocals}")
#
# print(f"varnames: {code.co_varnames}")
# print(f"names: {code.co_names}")
#
# print(f"cellvars: {code.co_cellvars}")
# print(f"freears: {code.co_freevars}")
#
# print(f"consts: {code.co_consts}")',
#     '_i4': 'dis.dis(add.__code__)',
#     '_i40': 'def g():
#     d = {}
#     def f():
#         d["a"] = 1
#     return f
#
# print(type(g()))
# print(type(g))
#
# code = g().__code__
#
# print(f"nlocals: {code.co_nlocals}")
#
# print(f"varnames: {code.co_varnames}")
# print(f"names: {code.co_names}")
#
# print(f"cellvars: {code.co_cellvars}")
# print(f"freears: {code.co_freevars}")
#
# print(f"consts: {code.co_consts}")',
#     '_i41': 'def g():
#     d = {}
#     def f():
#         d["a"] = 1
#     return f
#
#
# # obj = g()
# # obj is function f
# # code = g().__code__
# code = g().__code__
#
# print(f"nlocals: {code.co_nlocals}")
#
# print(f"varnames: {code.co_varnames}")
# print(f"names: {code.co_names}")
#
# print(f"cellvars: {code.co_cellvars}")
# print(f"freears: {code.co_freevars}")
#
# print(f"consts: {code.co_consts}")',
#     '_i42': 'def g():
#     d = {}
#     def f():
#         d["a"] = 1
#     return f
#
#
# def get_code_info(code):
#     print(f"nlocals: {code.co_nlocals}")
#
#     print(f"varnames: {code.co_varnames}")
#     print(f"names: {code.co_names}")
#
#     print(f"cellvars: {code.co_cellvars}")
#     print(f"freears: {code.co_freevars}")
#
#     print(f"consts: {code.co_consts}")
#
# # obj = g()
# # obj is function f
# # code = g().__code__
# code = g().__code__
# get_code_info(code)
#
# print(f"===================")
#
# code = g.__code__
# get_code_info(code)',
#     '_i43': 'def g():
#     d = {}
#     def f():
#         # 如果f里面没有使用d, 那么d就是一个varnames, 而不是一个cellvars
#         # d["a"] = 1
#     return f
#
# code = g.__code__
# get_code_info(code)',
#     '_i44': 'def g():
#     d = {}
#     def f():
#         # 如果f里面没有使用d, 那么d就是一个varnames, 而不是一个cellvars
#         # d["a"] = 1
#     return f
#
# def get_code_info(code):
#     print(f"nlocals: {code.co_nlocals}")
#
#     print(f"varnames: {code.co_varnames}")
#     print(f"names: {code.co_names}")
#
#     # cellvars: 这个variable会在其他scope用到
#     # freezers: 这个variable来自其他scope
#     print(f"cellvars: {code.co_cellvars}")
#     print(f"freears: {code.co_freevars}")
#
#     print(f"consts: {code.co_consts}")
#
# code = g.__code__
# get_code_info(code)',
#     '_i45': 'def g():
#     d = {}
#     def f():
#         # 如果f里面没有使用d, 那么d就是一个varnames, 而不是一个cellvars
#         # d["a"] = 1
#         pass
#     return f
#
# def get_code_info(code):
#     print(f"nlocals: {code.co_nlocals}")
#
#     print(f"varnames: {code.co_varnames}")
#     print(f"names: {code.co_names}")
#
#     # cellvars: 这个variable会在其他scope用到
#     # freezers: 这个variable来自其他scope
#     print(f"cellvars: {code.co_cellvars}")
#     print(f"freears: {code.co_freevars}")
#
#     print(f"consts: {code.co_consts}")
#
# code = g.__code__
# get_code_info(code)',
#     '_i46': 'import inspect
# from objprint import op
#
# def f():
#     frame = inspect.currentframe()
#
#     op(
#         frame,
#         honor_existing=False,
#         depth=2
#     )
#
# f()',
#     '_i47': 'import inspect
# from objprint import op
#
# def f():
#     frame = inspect.currentframe()
#
#     # op(
#     #     frame,
#     #     honor_existing=False,
#     #     depth=2
#     # )
#
# f()',
#     '_i48': 'import inspect
# # from objprint import op
#
# def f():
#     frame = inspect.currentframe()
#
#     # op(
#     #     frame,
#     #     honor_existing=False,
#     #     depth=2
#     # )
#
# f()',
#     '_i49': 'import inspect
# from objprint import op
#
# def f():
#     frame = inspect.currentframe()
#
#     op(
#         frame,
#         honor_existing=False,
#         depth=2
#     )
#
# f()',
#     '_i5': 'def outer(aa):
#     def inner():
#         bb = 1
#         return aa + bb + cc
#     return inner
#
# dis.dis(outer.__code__)',
#     '_i50': 'import inspect
# from objprint import op
#
# def f():
#     frame = inspect.currentframe()
#     print(frame)
#
#     # op(
#     #     frame,
#     #     honor_existing=False,
#     #     depth=2
#     # )
#
# f()',
#     '_i51': 'import inspect
# from objprint import op
#
# def f():
#     frame = inspect.currentframe()
#     # print(frame)
#
#     op(
#         frame,
#         honor_existing=False,
#         depth=2
#     )
#
# f()',
#     '_i52': 'import inspect
# from objprint import op
#
# def f():
#     frame = inspect.currentframe()
#     # print(frame)
#
#     op(
#         frame,
#         honor_existing=False,
#         depth=2
#     )
#
# f()',
#     '_i6': 'def add(a, b):
#     return a + b
#
# print(add(2, 3))',
#     '_i7': 'import dis
#
# dis.dis(add)',
#     '_i8': 'dis.dis(add.__code__)',
#     '_i9': 'def outer(aa):
#     def inner():
#         bb = 1
#         return aa + bb + cc
#     return inner
#
# dis.dis(outer.__code__)',
#     '_ih': [ ... ],
#     '_ii': 'import inspect
# from objprint import op
#
# def f():
#     frame = inspect.currentframe()
#     print(frame)
#
#     # op(
#     #     frame,
#     #     honor_existing=False,
#     #     depth=2
#     # )
#
# f()',
#     '_iii': 'import inspect
# from objprint import op
#
# def f():
#     frame = inspect.currentframe()
#
#     op(
#         frame,
#         honor_existing=False,
#         depth=2
#     )
#
# f()',
#     '_oh': { ... },
#     'add': <function add>,
#     'co': <code 0x7fa9a0a39450 ... >,
#     'code': <code 0x7fa990989a80 ... >,
#     'dis': <module 0x7fa980120e50 ... >,
#     'exit': <ZMQExitAutocall 0x7fa99072ac70 ... >,
#     'f': <function f>,
#     'g': <function g>,
#     'get_code_info': <function get_code_info>,
#     'get_ipython': <method 0x7fa9b07ff040 ... >,
#     'inspect': <module 0x7fa9b0141a40 ... >,
#     'mul': <function mul>,
#     'op': <ObjPrint 0x7fa9a004bc70 ... >,
#     'outer': <function outer>,
#     'quit': <ZMQExitAutocall 0x7fa99072ac70 ... >,
#     'source_code': '
# def toy_example(a, b):
#     x = a / (torch.abs(a) + 1)
#     if b.sum() < 0:
#         b = b * -1
#     return x * b
# '
#   },
#   .f_lasti = 18,
#   .f_lineno = 8,
#   .f_locals = {'frame': <frame 0x7fa95a760a70 ... >},
#   .f_trace = None,
#   .f_trace_lines = True,
#   .f_trace_opcodes = False
# >
